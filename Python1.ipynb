# %%
#Print your name, age, and favorite color.

name = "Pragathi"
age = 22
favorite_color = "red"

print(f"my name is {name}, my age is {age}, my favorite color is {favorite_color}")
# Out:
# my name is Pragathi, my age is 22, my favorite color is red

# %%
#Take two numbers as input and print their sum.

a = int(input("enter an element:"))
b = int(input("enter an element:"))
print("sum is:", a+b)
# Out:
# enter an element: 5
# enter an element: 6
# sum is: 11

# %%
#Convert temperature from Celsius to Fahrenheit

celsius = float(input("enter tempearture in celsius:"))
fahrenheit = (9/5 * celsius)+32
print("temperature in farhenheit is:", fahrenheit)
# Out:
# enter tempearture in celsius: 36
# temperature in farhenheit is: 96.8

# %%
#Calculate the area of a rectangle.
length = float(input("enter the length of rectangle:"))
breadth = float(input("enter the length of rectangle:"))
area= length * breadth
print("area of rectangle is:", area)
# Out:
# enter the length of rectangle: 5
# enter the length of rectangle: 4
# area of rectangle is: 20.0

# %%
#Swap two numbers using a temporary variable.

a = int(input("enter a number:"))
b = int(input("enter a number:"))
temp = a
a = b
b = temp
print(f"a is {a}, b is {b}")
# Out:
# enter a number: 5
# enter a number: 10
# a is 10, b is 5

# %%
#Swap two numbers without a temporary variable.
a = int(input("enter a number:"))
b = int(input("enter a number:"))
a = a + b
b = a - b
a = a - b
print(f"a is {a}, b is {b}")
# Out:
# enter a number: 10
# enter a number: 20
# 20
# 10

# %%
#Find the square and cube of a number.
num =int(input("enter side of square"))
square = num*num
cube = num*num*num
print("square of number is :",square)
print("cube of number is :",cube)
# Out:
# enter side of square 5
# square of number is : 25
# cube of number is : 125

# %%
#Convert minutes into hours and minutes.

min = int(input("time in minutes:"))
minutes = int(min%60)
hours = int(min/60)
print(f"{min}minutes in hours is {hours}hours and {minutes} minutes")
# Out:
# time in minutes: 145
# 145minutes in hours is 2hours and 25 minutes

# %%
principal = int(input("Enter principal: "))
time = int(input("Enter time: "))
rate = int(input("Enter rate: "))

SI = (principal * time * rate) / 100

print("Simple Interest is:", SI)
# Out:
# Enter principal:  1000
# Enter time:  10
# Enter rate:  2
# Simple Interest is: 200.0

# %%
#Calculate the average of three numbers.
a = float(input("enter a number:"))
b = float(input("enter a number:"))
c = float(input("enter a number:"))
average = (a+b+c)/3
print("average is :",average)
